# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('/content/Books.csv')
display(books.head())
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
# Lets remane some wierd columns name
books.rename(columns={"Book-Title":'title',
                      'Book-Author':'author',
                     "Year-Of-Publication":'year',
                     "Publisher":"publisher",
                     "Image-URL-L":"image_url"},inplace=True)

# %%
books.head(5)
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
users = pd.read_csv('/content/Users.csv')
#display(users.head())

# %%
users.shape
# Out:
# (239373, 3)

# %%
users.rename(columns={"User-ID":'user_id',
                      'Location':'location',
                     "Age":'age'},inplace=True)
users
# Out:
#         user_id                            location   age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings = pd.read_csv('/content/Ratings.csv')
display(ratings.head())
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X          0.0
# 1   276726  0155061224          5.0
# 2   276727  0446520802          0.0
# 3   276729  052165615X          3.0
# 4   276729  0521795028          6.0

# %%
ratings.rename(columns={"User-ID":'user_id',
                      'Book-Rating':'rating'},inplace=True)
ratings.head(5)
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X     0.0
# 1   276726  0155061224     5.0
# 2   276727  0446520802     0.0
# 3   276729  052165615X     3.0
# 4   276729  0521795028     6.0

# %%
print(books.shape, users.shape, ratings.shape, sep='\n')
# Out:
# (39462, 8)
# (239373, 3)
# (492084, 3)

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 98391      5891
# 35859      5850
# 278418     4533
# 76352      3367
#           ...
# 48880         1
# 48891         1
# 48892         1
# 48897         1
# 48865         1
# Name: count, Length: 45342, dtype: int64

# %%
ratings['user_id'].unique().shape
# Out:
# (45342,)

# %% [markdown]
# This step identifies users who have given more than 200 ratings. It helps filter active users to improve the reliability of the recommendation system.

# %%
x = ratings['user_id'].value_counts() > 200

# %%
x[x].shape
# Out:
# (453,)

# %%
#user IDs that satisfy the condition and stores them as an index.
y= x[x].index
y
# Out:
# Index([ 11676,  98391,  35859, 278418,  76352, 110973,  16795,  36836,  52584,
#         55492,
#        ...
#         83287, 110214,  88793,  33145, 116122,  44296,   9856,  73681,  59727,
#         28634],
#       dtype='int64', name='user_id', length=453)

# %%
#filters the ratings dataset to keep only the records of selected active users.
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#      user_id        ISBN  rating
# 412   276925  0006511929     0.0
# 413   276925  002542730X    10.0
# 414   276925  0060520507     0.0
# 415   276925  0060930934     0.0
# 416   276925  0060951303     0.0

# %%
ratings.shape
# Out:
# (279854, 3)

# %%
ratings_with_books = ratings.merge(books, on='ISBN')

# %%
ratings_with_books.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X    10.0
# 1   277427  0030615321     0.0
# 2   277427  0060002050     0.0
# 3   277427  0060192704     0.0
# 4   277427  0060542128     7.0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1   Ask for May, Settle for June (A Doonesbury book)      G. B. Trudeau  1982
# 2                  On a Wicked Dawn (Cynster Novels)  Stephanie Laurens  2002
# 3  Beauty Fades, Dumb Is Forever: The Making of a...     Judy Sheindlin  1999
# 4                              When the Storm Breaks     Heather Lowell  2003
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1        Henry Holt &amp; Co
# 2                 Avon Books
# 3         Cliff Street Books
# 4                HarperTorch
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
ratings_with_books.shape
# Out:
# (128705, 10)

# %% [markdown]
# This step calculates the total number of ratings for each book title. It helps identify which books are most frequently rated by users

# %%
number_rating = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
number_rating.head()
# Out:
#                                                title  rating
# 0   A Light in the Storm: The Civil War Diary of ...       2
# 1   Beyond IBM: Leadership Marketing and Finance ...       1
# 2   Final Fantasy Anthology: Official Strategy Gu...       3
# 3                                       It Takes Two       1
# 4   Q-Space (Star Trek The Next Generation, Book 47)       6

# %%
number_rating.rename(columns={'rating':'num_of_rating'},inplace=True)

# %%
final_rating = ratings_with_books.merge(number_rating, on='title')
final_rating.head(3)
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X    10.0
# 1   277427  0030615321     0.0
# 2   277427  0060002050     0.0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1   Ask for May, Settle for June (A Doonesbury book)      G. B. Trudeau  1982
# 2                  On a Wicked Dawn (Cynster Novels)  Stephanie Laurens  2002
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1        Henry Holt &amp; Co
# 2                 Avon Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/0030615321.0...
# 2  http://images.amazon.com/images/P/0060002050.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/0030615321.0...
# ...

# %%
final_rating.shape
# Out:
# (128705, 11)

# %%
 final_rating = final_rating[final_rating['num_of_rating'] >= 50]

# %%
final_rating.shape
# Out:
# (12650, 11)

# %%
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating.shape
# Out:
# (12126, 11)

# %%
book_pivot = final_rating.pivot_table(columns='user_id', index='title', values= 'rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     7.0
# A Map of the World                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# While I Was Gone                                       NaN     NaN     NaN
# White Oleander : A Novel                               0.0     NaN     NaN
# White Oleander : A Novel (Oprah's Book Club)           NaN     NaN     0.0
# Wicked: The Life and Times of the Wicked Witch ...     NaN     NaN     NaN
# Wild Animus                                            NaN     NaN     6.0
#
# ...

# %%
book_pivot.shape
# Out:
# (179, 440)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     7.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# While I Was Gone                                       0.0     0.0     0.0
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     6.0
#
# ...

# %%
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine, correlation

# %%
user_sim = 1 - pairwise_distances(book_pivot.values,metric='cosine')

# %%
user_sim
# Out:
# array([[1.        , 0.20861803, 0.14205909, ..., 0.16110735, 0.11672563,
#         0.10775256],
#        [0.20861803, 1.        , 0.09622333, ..., 0.        , 0.11953984,
#         0.08276283],
#        [0.14205909, 0.09622333, 1.        , ..., 0.        , 0.04629124,
#         0.08546537],
#        ...,
#        [0.16110735, 0.        , 0.        , ..., 1.        , 0.05978019,
#         0.07982072],
#        [0.11672563, 0.11953984, 0.04629124, ..., 0.05978019, 1.        ,
#         0.11732948],
#        [0.10775256, 0.08276283, 0.08546537, ..., 0.07982072, 0.11732948,
#         1.        ]])

# %%
np.fill_diagonal(user_sim, 0)

# %%
user_sim
# Out:
# array([[0.        , 0.20861803, 0.14205909, ..., 0.16110735, 0.11672563,
#         0.10775256],
#        [0.20861803, 0.        , 0.09622333, ..., 0.        , 0.11953984,
#         0.08276283],
#        [0.14205909, 0.09622333, 0.        , ..., 0.        , 0.04629124,
#         0.08546537],
#        ...,
#        [0.16110735, 0.        , 0.        , ..., 0.        , 0.05978019,
#         0.07982072],
#        [0.11672563, 0.11953984, 0.04629124, ..., 0.05978019, 0.        ,
#         0.11732948],
#        [0.10775256, 0.08276283, 0.08546537, ..., 0.07982072, 0.11732948,
#         0.        ]])

# %%
user_sim_df = pd.DataFrame(user_sim)

# %%
user_sim_df
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.000000  0.208618  0.142059  0.211273  0.137533  0.127749  0.101907
# 1    0.208618  0.000000  0.096223  0.000000  0.056489  0.218771  0.094831
# 2    0.142059  0.096223  0.000000  0.053726  0.280991  0.095090  0.174288
# 3    0.211273  0.000000  0.053726  0.000000  0.082864  0.093655  0.144528
# 4    0.137533  0.056489  0.280991  0.082864  0.000000  0.069943  0.068000
# ..        ...       ...       ...       ...       ...       ...       ...
# 174  0.000000  0.075715  0.050194  0.000000  0.150142  0.195251  0.018904
# 175  0.115123  0.053565  0.143625  0.000000  0.213385  0.228444  0.121795
# 176  0.161107  0.000000  0.000000  0.114692  0.089937  0.094148  0.122673
# 177  0.116726  0.119540  0.046291  0.132435  0.313475  0.118219  0.246012
# 178  0.107753  0.082763  0.085465  0.047543  0.127823  0.063456  0.129644
#
#           7         8         9    ...       169       170       171  \
# ...

# %%
user_book_matrix = final_rating.pivot_table(
    index='user_id',
    columns='title',
    values='rating'
).fillna(0)

# %%
from sklearn.metrics.pairwise import cosine_similarity

user_sim = cosine_similarity(user_book_matrix)
user_sim_df = pd.DataFrame(user_sim)

# %%
#user_sim_df.index = user_book_matrix.index
#user_sim_df.columns = user_book_matrix.index

# %%
#Set the index and column names to user ids
user_sim_df.index = final_rating.user_id.unique()
user_sim_df.columns = final_rating.user_id.unique()

# %%
user_sim_df
# Out:
#         276925    277427    277478  277639    278137   278188  278418  183     \
# 276925     1.0  0.000000  0.000000     0.0  0.000000  0.00000     0.0     0.0
# 277427     0.0  1.000000  0.437508     0.0  0.000000  0.00000     0.0     0.0
# 277478     0.0  0.437508  1.000000     0.0  0.000000  0.00000     0.0     0.0
# 277639     0.0  0.000000  0.000000     1.0  0.000000  0.00000     0.0     0.0
# 278137     0.0  0.000000  0.000000     0.0  1.000000  0.16862     0.0     0.0
# ...        ...       ...       ...     ...       ...      ...     ...     ...
# 116599     0.0  0.000000  0.000000     0.0  0.000000  0.00000     0.0     0.0
# 116931     0.0  0.000000  0.000000     0.0  0.000000  0.00000     0.0     0.0
# 117111     0.0  0.000000  0.000000     0.0  0.299078  0.00000     0.0     0.0
# 117251     0.0  0.000000  0.000000     0.0  0.000000  0.00000     0.0     0.0
# 117384     0.0  0.000000  0.000000     0.0  0.000000  0.00000     0.0     0.0
#
# ...

# %%
user_sim_df.idxmax(axis=1)
# Out:
# 277427    277427
# 277478    277478
# 277639    277639
# 278418    278418
# 254          254
#            ...
# 142524    142524
# 143175    143175
# 143253    277427
# 143415    143415
# 143792     70594
# Length: 440, dtype: int64

# %%
user_sim_df.iloc[0:5, 0:5]
# Out:
#           277427    277478    277639    278418  254
# 277427  1.000000  0.000000  0.000000  0.186865     0.0
# 277478  0.000000  1.000000  0.194178  0.000000     0.0
# 277639  0.000000  0.194178  1.000000  0.000000     0.0
# 278418  0.186865  0.000000  0.000000  1.000000     0.0
# 254     0.000000  0.000000  0.000000  0.000000     1.0

# %%
final_rating[(final_rating['user_id']==261528) | (final_rating['user_id']==277427)]
# Out:
#      user_id        ISBN  rating  \
# 7     277427  0060930535     0.0
# 9     277427  0060934417     0.0
# 11    277427  0061009059     9.0
# 22    277427  014100018X     0.0
# 24    277427  0142001740     0.0
# 28    277427  0312966091     0.0
# 31    277427  0316096199     0.0
# 33    277427  0316284955     0.0
# 34    277427  0316569321     0.0
# 36    277427  0316666343     0.0
# 37    277427  0316776963     8.0
# 45    277427  0345361792     0.0
# 53    277427  0374199698     0.0
# 67    277427  0385424736     9.0
# 69    277427  0385484518     0.0
# 73    277427  0385504209     8.0
# 81    277427  0399501487     9.0
# 87    277427  0425115801     0.0
# 102   277427  0425175405     0.0
# 106   277427  0439064872     0.0
# 107   277427  0439136369     0.0
# 123   277427  0440224764     7.0
# 125   277427  0440225701     0.0
# 127   277427  0440236703     0.0
# 129   277427  0440241073     0.0
# 134   277427  0446350982     9.0
# 142   277427  0446608890    10.0
# ...

# %%
print(user_sim_df.index.tolist()[:20])   # print first 20 index values
# Out:
# [277427, 277478, 277639, 278418, 254, 2276, 2766, 2977, 3363, 3757, 4017, 4385, 6242, 6251, 6323, 6543, 6563, 6575, 7158, 7286]

# %%
similar_users_277639 = user_sim_df.loc[277639]

# 2. Sort descending to get most similar users first
similar_users_277639 = similar_users_277639.sort_values(ascending=False)

# 3. View top 5 similar users (excluding themselves)
print(similar_users_277639.head(5))  # or head(n)
# Out:
# 277639    1.000000
# 141902    0.426806
# 81492     0.401148
# 52853     0.335521
# 127429    0.320980
# Name: 277639, dtype: float64

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
type(book_sparse)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm= 'brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
book_pivot.shape
# Out:
# (179, 440)

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[170,:].values.reshape(1,-1), n_neighbors=6 )

# %%
distance
# Out:
# array([[ 0.        , 29.39387691, 30.09983389, 30.21588986, 30.33150178,
#         31.08054054]])

# %%
suggestion
# Out:
# array([[170,  97,  26,  82, 153,  21]])

# %%
book_pivot.iloc[100:]
# Out:
# user_id                                             254     2276    2766    \
# title
# Suzanne's Diary for Nicholas                           0.0     0.0     0.0
# Tara Road                                              0.0     0.0     0.0
# Tears of the Giraffe (No.1 Ladies Detective Age...     0.0     0.0     0.0
# Tell No One                                            0.0     0.0     0.0
# The Alienist                                           0.0     0.0     0.0
# ...                                                    ...     ...     ...
# While I Was Gone                                       0.0     0.0     0.0
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     6.0
#
# ...

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['We Were the Mulvaneys',
#        'Songs in Ordinary Time (Oprah's Book Club (Paperback))',
#        'Cold Sassy Tree', 'Pop Goes the Weasel', 'The Smoke Jumper',
#        'Black Notice'],
#       dtype='object', name='title')

# %%
book_names = book_pivot.index

# %%
book_names[102]
# Out:
# 'Tears of the Giraffe (No.1 Ladies Detective Agency)'

# %%
'4 Blondes' in book_pivot.index
# Out:
# False

# %%
np.where(book_pivot.index == 'The Alienist')[0][0]
# Out:
# np.int64(104)

# %%
ids = np.where(final_rating['title'] == "Harry Potter and the Chamber of Secrets (Book 2)")[0][0]

# %%
final_rating.iloc[ids]['image_url']
# Out:
# 'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg'

# %%
book_name = []
for book_id in suggestion:
    book_name.append(book_pivot.index[book_id])

# %%
book_name[0]
# Out:
# Index(['We Were the Mulvaneys',
#        'Songs in Ordinary Time (Oprah's Book Club (Paperback))',
#        'Cold Sassy Tree', 'Pop Goes the Weasel', 'The Smoke Jumper',
#        'Black Notice'],
#       dtype='object', name='title')

# %%
ids_index = []
for name in book_name[0]:
    ids = np.where(final_rating['title'] == name)[0][0]
    ids_index.append(ids)

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6 )

    for i in range(len(suggestion)):
            books = book_pivot.index[suggestion[i]]
            for j in books:
                if j == book_name:
                    print(f"You searched '{book_name}'\n")
                    print("The suggestion books are: \n")
                else:
                    print(j)

# %%
book_name = "Harry Potter and the Chamber of Secrets (Book 2)"
recommend_book(book_name)
# Out:
# You searched 'Harry Potter and the Chamber of Secrets (Book 2)'
#
# The suggestion books are:
#
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# The Alienist
# Pop Goes the Weasel
# How Stella Got Her Groove Back

# %%
book_name = "The Alienist"
recommend_book(book_name)
# Out:
# You searched 'The Alienist'
#
# The suggestion books are:
#
# Pop Goes the Weasel
# The Smoke Jumper
# The Stone Diaries
# Disclosure
# Songs in Ordinary Time (Oprah's Book Club (Paperback))
